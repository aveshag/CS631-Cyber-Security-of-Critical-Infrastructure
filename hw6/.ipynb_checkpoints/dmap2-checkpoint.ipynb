# %%
# %matplotlib notebook
import pandas as pd
import numpy as np
from sklearn import metrics
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import pyDiffMap

data=pd.read_excel("HW_TESLA.xlt")        #reading data
feature_name=list(data.columns.values)
data=data.values
X = data[:,1:]                    #separating labels from features
y = data[:,0]

print(X.shape)
# Out:
# (4150, 132)

# %%
mydmap = dm.DiffusionMap.from_sklearn(n_evecs = 1, alpha = 0.5, epsilon = 'bgh', k=64)


dmap = mydmap.fit_transform(X)
# Out:
# [[1.24801810e-03 1.21345644e-03 1.17841865e-03 ... 2.69455844e-05
#   2.01280112e-05 1.17819970e-05]
#  [1.21345644e-03 1.18194671e-03 1.14986264e-03 ... 2.91656752e-05
#   2.18000310e-05 1.27709104e-05]
#  [1.17841865e-03 1.14986264e-03 1.12064732e-03 ... 3.15398343e-05
#   2.35889142e-05 1.38296474e-05]
#  ...
#  [2.69455844e-05 2.91656752e-05 3.15398343e-05 ... 4.59389375e-04
#   4.58703656e-04 3.65090082e-04]
#  [2.01280112e-05 2.18000310e-05 2.35889142e-05 ... 4.58703656e-04
#   6.50601403e-04 7.42167783e-04]
#  [1.17819970e-05 1.27709104e-05 1.38296474e-05 ... 3.65090082e-04
#   7.42167783e-04 1.22469336e-03]]
# (4150, 4150)

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=2, max_iter = 300) 
kmeans.fit(X_)

# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=2, n_init=10, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=2, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
correct = 0
zero=0
one=0
for i in range(len(X_)):
    predict_me = np.array(X_[i].astype(float))
    predict_me = predict_me.reshape(-1, len(predict_me))
    prediction = kmeans.predict(predict_me)
    prediction[0] = 1 - prediction[0]
    if (prediction[0]) == 0:
        zero += 1
    if (prediction[0]) == 1:
        one += 1
    if prediction[0] == y[i]:
        correct += 1

print(correct/len(X_))
print(zero)
print(one)
# Out:
# 0.43373493975903615
# 2976
# 1174

# %%
X_3 = X_[:,-3:]
print(X_3.shape)
# Out:
# (4150, 3)

# %%
kmeans.fit(X_3)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=2, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
correct = 0
zero = 0
one = 0
for i in range(len(X_3)):
    predict_me = np.array(X_3[i].astype(float))
    predict_me = predict_me.reshape(-1, len(predict_me))
    prediction = kmeans.predict(predict_me)
    #prediction[0] = 1 - prediction[0]
    if (prediction[0]) == 0:
        zero += 1
    if (prediction[0]) == 1:
        one += 1
    if prediction[0] == y[i]:
        correct += 1

print(correct/len(X_))
print(zero)
print(one)
# Out:
# 0.43373493975903615
# 2976
# 1174

# %%
fig1=plt.figure()
ax1=fig1.add_subplot(111,projection='3d')
ax1.scatter(X_3[:,0],X_3[:,1],X_3[:,2], marker='s',c=y ,cmap='RdBu')
fig2=plt.figure()
ax2=fig2.add_subplot(111,projection='3d')
ax2.scatter(X_3[:,0],X_3[:,1],X_3[:,2], marker='s',c=kmeans.labels_, cmap='RdBu')
fig2.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
