# %%
# %matplotlib notebook
import pandas as pd
import numpy as np
from sklearn import metrics
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

data=pd.read_excel("HW_TESLA.xlt")        #reading data
feature_name=list(data.columns.values)
data=data.values
X = data[:,1:]                    #separating labels from features
y = data[:,0]

print(X.shape)
# Out:
# (4150, 132)

# %%
kernel = metrics.pairwise.rbf_kernel(X, Y=None, gamma=None)
D = kernel.sum(axis=1)
D_inv = D**(-1/2)

D_inv_mat = np.diag(D_inv)

temp = np.dot(D_inv_mat, kernel) 
P_d = np.dot(kernel, D_inv_mat) 

print(P_d)
print(P_d.shape)
# Out:
# [[0.0353273  0.03434897 0.03335717 ... 0.00076274 0.00056976 0.00033351]
#  [0.03529598 0.03437945 0.03344622 ... 0.00084835 0.0006341  0.00037147]
#  [0.03520182 0.03434879 0.03347607 ... 0.00094216 0.00070465 0.00041312]
#  ...
#  [0.00125718 0.00136076 0.00147153 ... 0.02143337 0.02140138 0.01703372]
#  [0.00078912 0.00085467 0.00092481 ... 0.01798352 0.02550689 0.02909676]
#  [0.00033667 0.00036493 0.00039518 ... 0.01043245 0.02120745 0.03499562]]
# (4150, 4150)

# %%
w , v = np.linalg.eigh(P_d)

# %%
print(w)
X_ = v*(w.T)
# Out:
# [-0.69338953 -0.48194969 -0.39244084 ... 10.45279259 16.95636551
#  47.02057507]

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=2, max_iter = 300) 
kmeans.fit(X_)

# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=2, n_init=10, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=2, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
correct = 0
zero=0
one=0
for i in range(len(X_)):
    predict_me = np.array(X_[i].astype(float))
    predict_me = predict_me.reshape(-1, len(predict_me))
    prediction = kmeans.predict(predict_me)
    prediction[0] = 1 - prediction[0]
    if (prediction[0]) == 0:
        zero += 1
    if (prediction[0]) == 1:
        one += 1
    if prediction[0] == y[i]:
        correct += 1

print(correct/len(X_))
print(zero)
print(one)
# Out:
# 0.6992771084337349
# 2520
# 1630

# %%
X_3 = X_[:,-3:]
print(X_3.shape)
# Out:
# (4150, 3)

# %%
kmeans.fit(X_3)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=2, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
correct = 0
zero = 0
one = 0
for i in range(len(X_3)):
    predict_me = np.array(X_3[i].astype(float))
    predict_me = predict_me.reshape(-1, len(predict_me))
    prediction = kmeans.predict(predict_me)
    #prediction[0] = 1 - prediction[0]
    if (prediction[0]) == 0:
        zero += 1
    if (prediction[0]) == 1:
        one += 1
    if prediction[0] == y[i]:
        correct += 1

print(correct/len(X_))
print(zero)
print(one)
# Out:
# 0.7262650602409638
# 2488
# 1662

# %%
fig1=plt.figure()
ax1=fig1.add_subplot(111,projection='3d')
ax1.scatter(X_3[:,0],X_3[:,1],X_3[:,2], marker='s',c=y ,cmap='RdBu')
fig2=plt.figure()
ax2=fig2.add_subplot(111,projection='3d')
ax2.scatter(X_3[:,0],X_3[:,1],X_3[:,2], marker='s',c=kmeans.labels_, cmap='RdBu')
fig2.show()
# Out:
# <img src="data:image/png;base64,..." width="409">
# <img src="data:image/png;base64,..." width="640">
